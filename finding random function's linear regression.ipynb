# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = 4 * np.random.rand(100,1)
y = 12 + (3 * x) + np.random.rand(100,1)

# %%
plt.scatter(x,y)
plt.xlabel("X",fontsize = 15)
plt.ylabel("Y",fontsize = 15, rotation = 0)
plt.show()

# %%
def analyticsMethod(x, y):
    ssxy = (x * y).sum() - (len(x) * x.mean() * y.mean())
    ssxx = ((x - x.mean()) ** 2).sum()
    m = ssxy / ssxx
    c = y.mean() - (m * x.mean())
    return [m,c]

# %%
m, c = analyticsMethod(x, y)
print(f'M (Theta 0) değeri: {m}')
print(f'C (Theta 1) değeri: {c}')
# Out:
# M (Theta 0) değeri: 2.9939324011207535
# C (Theta 1) değeri: 12.552372964920362

# %%
plt.scatter(x, y)
plt.plot(x, (x * m + c), color = "red")
plt.xlabel("X", fontsize = 15)
plt.ylabel("Y", fontsize = 15, rotation = 0)
plt.show()
